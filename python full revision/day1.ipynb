# %% [markdown]
# ## DAY 1 — Python Introduction
#
# ## TOPICS
# Python के हो
# print()
# comments
# variables
# naming rules
# Learn
# print()
# print("Hello")
#
# Output देखाउँछ।
#
# Variables
# name = "Nirmal"
# age = 18
#
# data store गर्छ।
#
# ## Naming Rules
#
# ✅ Correct
#
# user_name
# age1
#
# ❌ Wrong
#
# 1age
# user-name
# Practice
#
# ✅ name print
# ✅ age print
# ✅ school print
# ✅ bio print

# %% [markdown]
# ## 🟢 PART 1 — print()

# %% [markdown]
# QUESTION 1
# Print Hello World

# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# ## QUESTION 2
# Print Your Name

# %%
print("my name is nirmal saud")
# Out:
# my name is nirmal saud

# %% [markdown]
# ## QUESTION 3
# Print Your Age

# %%
print(18)
# Out:
# 18

# %% [markdown]
# ## QUESTION 4
# Print Multiple Lines

# %%
print("nirmal")
print("kathmandu")
print(18)
# Out:
# nirmal
# kathmandu
# 18

# %% [markdown]
# ## QUESTION 5
# Print Addition

# %%
print(10+20)
# Out:
# 30

# %% [markdown]
# ## 🟡 PART 2 — VARIABLES

# %% [markdown]
# ## QUESTION 6
# Create Name Variable

# %%
name = "nirmal"
print(name)
# Out:
# nirmal

# %% [markdown]
# ## QUESTION 7
# Create Age Variable

# %%
age = 18
print(age)
# Out:
# 18

# %% [markdown]
# ## QUESTION 8
# Create Country Variable

# %%
country = "nepal"
print(country)
# Out:
# nepal

# %% [markdown]
# ## QUESTION 9
# Multiple Variables

# %%
name = "Nirmal"
age = 18
country = "Nepal"

print(name)
print(age)
print(country)
# Out:
# Nirmal
# 18
# Nepal

# %% [markdown]
# ## QUESTION 10
# Add Two Variables

# %%
a = 20
b = 30
print(a + b)
# Out:
# 50

# %% [markdown]
# ## 🟠 PART 3 — DATATYPES

# %% [markdown]
# ## QUESTION 11
# Integer Variable

# %%
age = 18

print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# ## QUESTION 12
# Float Variable

# %%
price = 99.99
print(type(price))
# Out:
# <class 'float'>

# %% [markdown]
# ## QUESTION 13
# String Variable

# %%
name = "python"
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# ## QUESTION 14
# Boolean Variable

# %%
is_student = True
print(type(is_student))
# Out:
# <class 'bool'>

# %% [markdown]
# ## QUESTION 15
# Print All Types

# %%
a = 10
b = 5.5
c = "Hello"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## 🔵 PART 4 — USER INPUT

# %% [markdown]
# ## QUESTION 16
# Input Name

# %%
name =(input("enter your name:"))
print(name)
# Out:
# nirmal

# %% [markdown]
# ## QUESTION 17
# Input Age

# %%
age = input("enter your age")
print(age)
# Out:
# 18

# %% [markdown]
# ## QUESTION 18
# Input and Greeting

# %%
name = input("Enter name: ")

print("Hello", name)
# Out:
# Hello nirmal

# %% [markdown]
# ## QUESTION 19
# Input Two Numbers

# %%
a = input("enter a first number")
b = input("enter a second number")
print(a+b)
# Out:
# 3070

# %% [markdown]
# ## QUESTION 20
# User Age Message

# %%
age = int(input("Enter age: "))

print("You are", age, "years old")
# Out:
# You are 18 years old

# %% [markdown]
# ## 🟣 PART 5 — BASIC CALCULATIONS

# %% [markdown]
# ## QUESTION 21
# Rectangle Area

# %%
length = 10
breadth = 5

area = length * breadth

print(area)
# Out:
# 50

# %% [markdown]
# Formula:
#
# Area=l×b

# %% [markdown]
# ## QUESTION 22
# Square

# %%
num = 5
print(num ** 2)
# Out:
# 25

# %% [markdown]
# ## QUESTION 23
# Cube

# %%
num = 5
print(num ** 3)
# Out:
# 125

# %% [markdown]
# ## QUESTION 24
# Average

# %%
a = 10
b = 20
c = 30

avg = (a + b + c) / 3

print(avg)
# Out:
# 20.0

# %% [markdown]
# ## QUESTION 25
# Celsius to Fahrenheit

# %%
c = 30

f = (9/5 * c) + 32

print(f)
# Out:
# 86.0

# %% [markdown]
# ## 🔴 PART 6 — MINI TASKS

# %% [markdown]
# ## Student Bio

# %%
name = "nirmal"
age = 18
school = "texas international college"
place = "kathmandu"


print(name)
print(age)
print(school)
print(place)
# Out:
# nirmal
# 18
# texas international college
# kathmandu

# %% [markdown]
# ## QUESTION 27
# Salary Bonus

# %%
salary = 50000

bonus = salary * 0.10

print(bonus)
# Out:
# 5000.0

# %% [markdown]
# ## QUESTION 28
# Total Marks

# %%
math = 80
science = 70
english = 90

total = math + science + english

print(total)
# Out:
# 240

# %% [markdown]
# ## QUESTION 29
# Percentage

# %%
obtained = 450
total = 500

percentage = (obtained / total) * 100

print(percentage)
# Out:
# 90.0

# %% [markdown]
# ## QUESTION 30
# Beautiful Intro Program

# %%
name = input("Enter name: ")
age = int(input("Enter age: "))
country = input("Enter country: ")

print("My name is", name)
print("I am", age, "years old")
print("I live in", country)
# Out:
# My name is nirmal
# I am 18 years old
# I live in nepal

# %% [markdown]
# ## 🔥 DAY 1 MASTER TOPICS
#
# ✅ print()
# ✅ variables
# ✅ input()
# ✅ type()
# ✅ int float str bool
# ✅ calculations
# ✅ user input

# %% [markdown]
# ## 🔥 AFTER COMPLETING DAY 1
#
# तिमीले:
#
# variable बुझ्छौ
# input/output बुझ्छौ
# datatype बुझ्छौ
# beginner calculations गर्न सक्छौ
