# %% [markdown]
# ## 🚀 DAY 2 — OPERATORS + IF ELSE + LOGIC BUILDING
# TODAY GOAL 🎯

# %% [markdown]
# ## आज तिमीले सिक्ने:
#
# ✅ arithmetic operators
# ✅ comparison operators
# ✅ logical operators
# ✅ assignment operators
# ✅ if else
# ✅ elif
# ✅ nested if
# ✅ logic building

# %% [markdown]
# ## 🟢 ARITHMETIC OPERATORS
# 1️⃣ Addition

# %%
a = 10
b = 30
print(a +b)
# Out:
# 40

# %% [markdown]
# 2️⃣ Subtraction

# %%
a  = 10
b = 30
print(a - b)
# Out:
# True

# %% [markdown]
# 3️⃣ Multiplication

# %%
a = 10
b = 30
print(a *b)
# Out:
# 300

# %% [markdown]
# 4️⃣ Division

# %%
a = 10
b = 20
print(a/b)
# Out:
# 0.5

# %% [markdown]
# 5️⃣ Modulus

# %%
a = 10
b = 30
print(a%b)
# Out:
# 10

# %% [markdown]
# 6️⃣ Floor Division

# %%
a = 10
b = 30
print(a // b)
# Out:
# 0

# %% [markdown]
# 7️⃣ Power Operator

# %%
a = 10
b = 30
print(10 ** 30)
# Out:
# 1000000000000000000000000000000

# %% [markdown]
# 8️⃣ Add Variables

# %%
a = 39
b = 29
print(a + b)
# Out:
# 68

# %% [markdown]
# 1️⃣1️⃣ User Input Addition

# %%
a = int(input("enter a num"))
b = int(input("enter a num"))
print(a + b)
# Out:
# 70

# %% [markdown]
# 1️⃣2️⃣ User Input Subtraction

# %%
a = int(input("enter a num"))
b = int(input("enter a num"))
print(a - b)
# Out:
# -60

# %% [markdown]
# 1️⃣3️⃣ User Input Multiplication

# %%
a = int(input("enter a num"))
b = int(input("enter a num"))
print(a * b)
# Out:
# 3510

# %% [markdown]
# 1️⃣4️⃣ User Input Division

# %%
a = int(input("enter a num"))
b = int(input("enter a num"))
print(a / b)
# Out:
# 12.0

# %% [markdown]
# 1️⃣5️⃣ Square Number

# %%
num = 5

print(num ** 2)
# Out:
# 25

# %% [markdown]
# 1️⃣6️⃣ Cube Number

# %%
num = 3

print(num ** 3)
# Out:
# 27

# %% [markdown]
# 1️⃣7️⃣ Area Rectangle

# %%
a = 20
b = 30
print(a * b)
# Out:
# 600

# %% [markdown]
# 1️⃣8️⃣ Area Triangle

# %%
base = 10
height = 5

print(0.5 * base * height)
# Out:
# 25.0

# %% [markdown]
# 1️⃣9️⃣ Circle Area

# %%
radius = 7

print(3.14 * radius ** 2)
# Out:
# 153.86

# %% [markdown]
# 2️⃣0️⃣ Average of 3 Numbers

# %%
a = 10
b = 20
c = 30

print((a + b + c) / 3)
# Out:
# 20.0

# %% [markdown]
# 🟡 COMPARISON OPERATORS

# %% [markdown]
# 2️⃣1️⃣ Equal To

# %%
print(10 == 10)
# Out:
# True

# %% [markdown]
# 2️⃣2️⃣ Not Equal

# %%
print(10 != 5)
# Out:
# True

# %% [markdown]
# 2️⃣3️⃣ Greater Than

# %%
print(20 > 10)
# Out:
# True

# %% [markdown]
# 2️⃣4️⃣ Less Than

# %%
print(5 < 10)
# Out:
# True

# %% [markdown]
# 2️⃣5️⃣ Greater Equal

# %%
print(18 >= 18)
# Out:
# True

# %% [markdown]
# 2️⃣6️⃣ Less Equal

# %%
print(5 <= 10)
# Out:
# True

# %% [markdown]
# 🟠 LOGICAL OPERATORS

# %% [markdown]
# 2️⃣7️⃣ AND Operator

# %%
print(10 > 5 and 20 > 10)
# Out:
# True

# %% [markdown]
# 2️⃣8️⃣ OR Operator

# %%
print(10 > 100 or 20 > 10)
# Out:
# True

# %% [markdown]
# 2️⃣9️⃣ NOT Operator

# %%
print(not True)
# Out:
# False

# %% [markdown]
# 3️⃣0️⃣ Complex Logical

# %%
print(10 > 5 and 5 < 2)
# Out:
# False

# %% [markdown]
# 🔥 OPERATORS YOU MASTERED

# %% [markdown]
# | Operator | Meaning       |
# | -------- | ------------- |
# | +        | add           |
# | -        | subtract      |
# | *        | multiply      |
# | /        | divide        |
# | %        | remainder     |
# | //       | floor divide  |
# | **       | power         |
# | ==       | equal         |
# | !=       | not equal     |
# | >        | greater       |
# | <        | less          |
# | >=       | greater equal |
# | <=       | less equal    |
# | and      | both true     |
# | or       | one true      |
# | not      | opposite      |

# %% [markdown]
# ## PHASE 2

# %% [markdown]
# 1️⃣1️⃣ Swap Variables

# %%
a = 5
b = 10

a, b = b, a

print(a)
print(b)
# Out:
# 10
# 5

# %% [markdown]
# 1️⃣2️⃣ Minutes to Seconds

# %%
minute = 5
print(minute * 60)
# Out:
# 300

# %% [markdown]
# 1️⃣3️⃣ Hours to Minutes

# %%
hr = 1
print(hr * 60)
# Out:
# 60

# %% [markdown]
# 1️⃣4️⃣ Kilometer to Meter

# %%
km = 5

print(km * 1000)
# Out:
# 5000

# %% [markdown]
# 1️⃣5️⃣ Days to Years

# %%
day = 730
print(day / 365)
# Out:
# 2.0

# %% [markdown]
# 🔥 MIXED QUESTIONS

# %% [markdown]
# 4️⃣1️⃣ Calculator

# %%
a = 10
b = 5

print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 15
# 5
# 50
# 2.0

# %% [markdown]
# 4️⃣2️⃣ BMI

# %%
weight = 60
height = 1.7

bmi = weight / (height ** 2)

print(bmi)
# Out:
# 20.761245674740486

# %% [markdown]
# 4️⃣3️⃣ Percentage

# %%
obtained = 450
total = 500

print((obtained / total) * 100)
# Out:
# 90.0

# %% [markdown]
# 4️⃣4️⃣ Multiple of 10 and 5

# %%
num = 50

print(num % 10 == 0 and num % 5 == 0)
# Out:
# True

# %% [markdown]
# 4️⃣5️⃣ Profit Loss

# %%
cp = 100
sp = 150

print(sp - cp)
# Out:
# 50

# %% [markdown]
# 4️⃣6️⃣ Speed Formula

# %%
distance = 100
time = 2

print(distance / time)
# Out:
# 50.0

# %% [markdown]
# 4️⃣7️⃣ Leap Year

# %%
year = 2024

print(year % 4 == 0)
# Out:
# True

# %% [markdown]
# 4️⃣8️⃣ Range Check

# %%
num = 50

print(num >= 1 and num <= 100)
# Out:
# True

# %% [markdown]
# 4️⃣9️⃣ Username Password Check

# %%
username = "admin"
password = "1234"

print(username == "admin" and password == "1234")
# Out:
# True

# %% [markdown]
# 5️⃣0️⃣ Advanced Calculator

# %%
a = 20
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
print(a // b)
print(a ** b)
# Out:
# 23
# 17
# 60
# 6.666666666666667
# 2
# 6
# 8000
