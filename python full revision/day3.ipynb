# %% [markdown]
# IF ELSE MASTERY
# 50 QUESTIONS WITH ANSWERS
# SIMPLE → MEDIUM → ADVANCED

# %% [markdown]
# 🟢 SIMPLE IF ELSE QUESTIONS

# %% [markdown]
# 1️⃣ Positive or Negative

# %%
num = int(input())

if num > 0:
    print("Positive")

else:
    print("Negative")
# Out:
# Positive

# %% [markdown]
# 2️⃣ Even Odd

# %%
num = int(input())

if num % 2 == 0:
    print("Even")

else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# 3️⃣ Voting Eligibility

# %%
age = int(input())

if age >= 18:
    print("Can Vote")

else:
    print("Cannot Vote")
# Out:
# Can Vote

# %% [markdown]
# 4️⃣ Adult Minor

# %%
age = int(input())

if age >= 18:
    print("Adult")

else:
    print("Minor")
# Out:
# Adult

# %% [markdown]
# 5️⃣ Pass Fail

# %%
marks = int(input())

if marks >= 40:
    print("Pass")

else:
    print("Fail")
# Out:
# Fail

# %% [markdown]
# 6️⃣ Divisible by 5

# %%
num = int(input())

if num % 5 == 0:
    print("Divisible")

else:
    print("Not Divisible")

# %% [markdown]
# 7️⃣ Greater Number

# %%
a = input("num")
b = input("num")

if a>b:
    print(a)
else:
    print(b)
# Out:
# 6

# %% [markdown]
# 8️⃣ Equal Numbers

# %%
a = int(input())
b = int(input())

if a == b:
    print("Equal")

else:
    print("Not Equal")
# Out:
# Not Equal

# %% [markdown]
# 9️⃣ Username Check

# %%
username = input()

if username == "nirmal":
    print("Correct")

else:
    print("Wrong")
# Out:
# Correct

# %% [markdown]
# 🔟 Password Checker

# %%
password = input("password")
if password == "harekrishna":
    print("correct password")
else:
    print("wrong password")
# Out:
# correct password

# %% [markdown]
# 🟡 MEDIUM LEVEL QUESTIONS

# %% [markdown]
# 1️⃣1️⃣ Positive Negative Zero

# %%
num = int(input())

if num > 0:
    print("Positive")

elif num < 0:
    print("Negative")

else:
    print("Zero")
# Out:
# Positive

# %% [markdown]
# 1️⃣2️⃣ Grading System

# %%
marks = int(input("enter a marks"))

if marks >= 80:
    print("destination")

elif marks >= 70:
    print("pass")

else:
    print("fail")
# Out:
# fail

# %% [markdown]
# 1️⃣3️⃣ Biggest Among 3

# %%
a = int(input("enter a  first number"))
b = int(input("enter a  second number"))
c = int(input("enter a  third number"))

if a>b and a>c:
    print(a)
elif b>a and b>c:
    print(b)
else:
    print(c)
# Out:
# 78

# %% [markdown]
# 1️⃣4️⃣ Smallest Among 3

# %%
a = int(input())
b = int(input())
c = int(input())

if a < b and a < c:
    print(a)

elif b < a and b < c:
    print(b)

else:
    print(c)
# Out:
# 67

# %% [markdown]
# 1️⃣5️⃣ Leap Year

# %%
year = int(input())

if year % 4 == 0:
    print("Leap Year")

else:
    print("Not Leap Year")
# Out:
# Not Leap Year

# %% [markdown]
# 1️⃣6️⃣ Divisible by 3 and 5

# %%
num = int(input())

if num % 3 == 0 and num % 5 == 0:
    print("Divisible")

else:
    print("Not Divisible")
# Out:
# Not Divisible

# %% [markdown]
# 1️⃣7️⃣ Multiple of 10

# %%
num = int(input())

if num % 10 == 0:
    print("Multiple of 10")

else:
    print("Not Multiple")
# Out:
# Not Multiple

# %% [markdown]
# 1️⃣8️⃣ ATM Withdraw

# %%
balance = 5000

withdraw = int(input())

if withdraw <= balance:
    print("Withdraw Successful")

else:
    print("Insufficient Balance")
# Out:
# Withdraw Successful

# %% [markdown]
# 1️⃣9️⃣ Login System

# %%
username = input()
password = input()

if username == "admin" and password == "1234":
    print("Login Success")

else:
    print("Login Failed")
# Out:
# Login Failed

# %% [markdown]
# 2️⃣0️⃣ Temperature Check

# %%
temp = int(input())

if temp > 30:
    print("Hot")

else:
    print("Cold")
# Out:
# Hot

# %% [markdown]
# 🟠 ADVANCED BEGINNER QUESTIONS

# %% [markdown]
# 2️⃣1️⃣ Electricity Bill

# %%
unit = int(input())

if unit <= 100:
    print(unit * 5)

else:
    print(unit * 10)
# Out:
# 280

# %% [markdown]
# 2️⃣2️⃣ Bonus Salary

# %%
salary = int(input())

if salary >= 50000:
    print("Bonus Added")

else:
    print("No Bonus")

# %% [markdown]
# 2️⃣3️⃣ Character Check

# %%
char = input()

if char == "a":
    print("Vowel")

else:
    print("Consonant")
# Out:
# Vowel

# %% [markdown]
# 2️⃣4️⃣ Teenager Check

# %%
age = int(input())

if age >= 13 and age <= 19:
    print("Teenager")

else:
    print("Not Teenager")
# Out:
# Not Teenager

# %% [markdown]
# 2️⃣5️⃣ Username Length

# %%
username = input()

if len(username) >= 5:
    print("Valid")

else:
    print("Too Short")
# Out:
# Valid

# %% [markdown]
# 2️⃣6️⃣ Number Range Check

# %%
num = int(input())

if num >= 1 and num <= 100:
    print("Inside Range")

else:
    print("Outside Range")
# Out:
# Inside Range

# %% [markdown]
# 2️⃣7️⃣ BMI Checker

# %%
weight = 60
height = 1.7

bmi = weight / (height ** 2)

if bmi >= 25:
    print("Overweight")

else:
    print("Normal")
# Out:
# Normal

# %% [markdown]
# 2️⃣8️⃣ Profit Loss

# %%
cp = 100
sp = 150

if sp > cp:
    print("Profit")

else:
    print("Loss")
# Out:
# Profit

# %% [markdown]
# 2️⃣9️⃣ Speed Check

# %%
speed = int(input())

if speed > 80:
    print("Over Speed")

else:
    print("Normal Speed")
# Out:
# Normal Speed

# %% [markdown]
# 3️⃣0️⃣ Number Sign

# %%
num = int(input())
if num > 0:
    print("+")

elif num < 0:
    print("-")

else:
    print("0")
# Out:
# +

# %% [markdown]
# 🔵 NESTED IF QUESTIONS

# %% [markdown]
# 3️⃣1️⃣ Nested Age Check

# %%
age = int(input())
citizen = True

if age >= 18:

    if citizen:
        print("Eligible")

    else:
        print("Not Citizen")

else:
    print("Under Age")
# Out:
# Eligible

# %% [markdown]
# 3️⃣2️⃣ Nested Login

# %%
username = input()
password = input()

if username == "admin":

    if password == "1234":
        print("Login Success")

    else:
        print("Wrong Password")

else:
    print("Wrong Username")

# %% [markdown]
# 3️⃣3️⃣ Marks Scholarship

# %%
marks = int(input())

if marks >= 80:

    if marks >= 90:
        print("Full Scholarship")

    else:
        print("Half Scholarship")

else:
    print("No Scholarship")
# Out:
# No Scholarship

# %% [markdown]
# 3️⃣4️⃣ ATM PIN

# %%
pin = input()

if pin == "1234":

    amount = int(input())

    if amount <= 5000:
        print("Withdraw Success")

    else:
        print("Insufficient Balance")

else:
    print("Wrong PIN")
# Out:
# Wrong PIN

# %% [markdown]
# 3️⃣5️⃣ Exam Eligibility

# %%
attendance = 80

if attendance >= 75:

    fees = True

    if fees:
        print("Eligible")

    else:
        print("Pay Fees")

else:
    print("Low Attendance")

# %% [markdown]
# 🔴 HARD IF ELSE QUESTIONS

# %% [markdown]
# 3️⃣6️⃣ Calculator

# %%
a = int(input())
b = int(input())

op = input()

if op == "+":
    print(a + b)

elif op == "-":
    print(a - b)

elif op == "*":
    print(a * b)

elif op == "/":
    print(a / b)

else:
    print("Invalid")

# %% [markdown]
# 3️⃣7️⃣ Largest of 4 Numbers

# %%
a = 10
b = 20
c = 30
d = 40

if a > b and a > c and a > d:
    print(a)

elif b > a and b > c and b > d:
    print(b)

elif c > a and c > b and c > d:
    print(c)

else:
    print(d)
# Out:
# 40

# %% [markdown]
# 3️⃣8️⃣ Password Strength

# %%
password = input()

if len(password) >= 8:
    print("Strong")

else:
    print("Weak")
# Out:
# Weak

# %% [markdown]
# 3️⃣9️⃣ Bank Loan Eligibility

# %%
salary = 60000
age = 25

if salary >= 50000 and age >= 21:
    print("Eligible")

else:
    print("Not Eligible")
# Out:
# Eligible

# %% [markdown]
# 4️⃣0️⃣ Online Shopping Discount

# %%
amount = 6000

if amount >= 5000:
    print("20% Discount")

else:
    print("No Discount")
# Out:
# 20% Discount

# %% [markdown]
# 🔥 EXPERT BEGINNER QUESTIONS

# %% [markdown]
# 4️⃣1️⃣ Triangle Validity

# %%
a = 60
b = 60
c = 60

if a + b + c == 180:
    print("Valid Triangle")

else:
    print("Invalid Triangle")
# Out:
# Valid Triangle

# %% [markdown]
# 4️⃣2️⃣ Vowel Checker

# %%
char = input()

if char in "aeiou":
    print("Vowel")

else:
    print("Consonant")
# Out:
# Vowel

# %% [markdown]
# 4️⃣3️⃣ Prime Check

# %%
num = int(input())

if num > 1:

    if num % 2 != 0:
        print("Prime Maybe")

    else:
        print("Not Prime")

else:
    print("Invalid")

# %% [markdown]
# 4️⃣4️⃣ Student Result

# %%
math = 50
science = 60
english = 70

if math >= 40 and science >= 40 and english >= 40:
    print("Pass")

else:
    print("Fail")
# Out:
# Pass

# %% [markdown]
# 4️⃣5️⃣ Internet Data Check

# %%
data = 0

if data > 0:
    print("Internet Available")

else:
    print("No Data")
# Out:
# No Data

# %% [markdown]
# 4️⃣6️⃣ Mobile Battery

# %%
battery = 15

if battery <= 20:
    print("Low Battery")

else:
    print("Battery OK")

# %% [markdown]
# 4️⃣7️⃣ Height Eligibility

# %%
height = 5.8

if height >= 5.5:
    print("Eligible")

else:
    print("Not Eligible")
# Out:
# Eligible

# %% [markdown]
# 4️⃣8️⃣ Ticket Booking

# %%
seats = 5

if seats > 0:
    print("Book Ticket")

else:
    print("Housefull")
# Out:
# Book Ticket

# %% [markdown]
# 4️⃣9️⃣ Course Eligibility

# %%
marks = 75

if marks >= 70:
    print("Eligible for Course")

else:
    print("Not Eligible")
# Out:
# Eligible for Course

# %% [markdown]
# 5️⃣0️⃣ Final Challenge

# %%
username = input()
password = input()

if username == "admin" and password == "1234":
    print("Welcome Admin")

elif username == "admin":
    print("Wrong Password")

else:
    print("Access Denied")
